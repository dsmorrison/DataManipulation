# %% [markdown]
# # Data Manipulation Studio
#
# For this studio, we will revisit our California farmers looking for advice on growing pumpkins and the same [pumpkins dataset](https://www.kaggle.com/usda/a-year-of-pumpkin-prices) as provided by the U.S. Department of Agriculture. You may have to clean data in the process of data manipulation, so feel free to pull up your notebook from the last class's studio.
#
# We will now be focusing our attention on a different region in the United States, the Northeast. When you open up the `dataset` folder, you will have 13 CSVs, including the San Francisco and Los Angeles data from the last lesson. The 13 CSVs are each a different terminal market in the United States.
#
# ## Getting Started
#
# Import the CSVs for each of the following cities: Baltimore, Boston, New York, and Philadelphia. Set up a dataframe for each city.

# %%
# Import the necessary libraries and CSVs. Make some dataframes!
import pandas as pd

#incredibly frustrating!!!! 

baltimore_df = pd.read_csv('baltimore_9-24-2016_9-30-2017.csv')
boston_df= pd.read_csv('boston_9-24-2016_9-30-2017.csv')
philly_df = pd.read_csv('philadelphia_9-24-2016_9-30-2017.csv')
newyork_df = pd.read_csv('new-york_9-24-2016_9-30-2017.csv')

# %% [markdown]
# ## Clean Your Data
#
# In the last lesson, we cleaned the data to related to San Francisco. Pull up your notebook from the last lesson and use your cleaning skills to clean the dataframes as necessary.

# %%
# Clean your data here!
northeast_region=pd.concat([baltimore_df, boston_df, philly_df, newyork_df,])
northeast_region
# ignore_index=True
# Out:
#     Commodity Name  City Name  Type              Package      Variety  \
# 0         PUMPKINS  BALTIMORE   NaN         24 inch bins          NaN
# 1         PUMPKINS  BALTIMORE   NaN         24 inch bins          NaN
# 2         PUMPKINS  BALTIMORE   NaN         24 inch bins  HOWDEN TYPE
# 3         PUMPKINS  BALTIMORE   NaN         24 inch bins  HOWDEN TYPE
# 4         PUMPKINS  BALTIMORE   NaN         24 inch bins  HOWDEN TYPE
# ..             ...        ...   ...                  ...          ...
# 107       PUMPKINS   NEW YORK   NaN       bushel cartons    MINIATURE
# 108       PUMPKINS   NEW YORK   NaN  1 1/9 bushel crates    MINIATURE
# 109       PUMPKINS   NEW YORK   NaN  1 1/9 bushel crates    MINIATURE
# 110       PUMPKINS   NEW YORK   NaN  1 1/9 bushel crates    MINIATURE
# 111       PUMPKINS   NEW YORK   NaN  1 1/9 bushel crates    MINIATURE
#
#     Sub Variety  Grade        Date  Low Price  High Price  ...  Color  \
# 0           NaN    NaN  04/29/2017        270       280.0  ...    NaN
# 1           NaN    NaN  05/06/2017        270       280.0  ...    NaN
# 2           NaN    NaN  09/24/2016        160       160.0  ...    NaN
# 3           NaN    NaN  09/24/2016        160       160.0  ...    NaN
# 4           NaN    NaN  11/05/2016         90       100.0  ...    NaN
# ..          ...    ...         ...        ...         ...  ...    ...
# 107         NaN    NaN  09/09/2017         32        32.0  ...    NaN
# 108  ROUND TYPE    NaN  10/08/2016         18        18.0  ...    NaN
# 109  ROUND TYPE    NaN  10/08/2016         18        18.0  ...    NaN
# 110  ROUND TYPE    NaN  10/15/2016         18        18.0  ...    NaN
# 111  ROUND TYPE    NaN  10/15/2016         18        18.0  ...    NaN
#
#      Environment Unit of Sale Quality Condition Appearance  Storage Crop  \
# 0            NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 1            NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 2            NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 3            NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 4            NaN          NaN     NaN       NaN        NaN      NaN  NaN
# ..           ...          ...     ...       ...        ...      ...  ...
# 107          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 108          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 109          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 110          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 111          NaN          NaN     NaN       NaN        NaN      NaN  NaN
#
#      Repack  Trans Mode
# 0         E         NaN
# 1         E         NaN
# 2         N         NaN
# 3         N         NaN
# 4         N         NaN
# ..      ...         ...
# 107       N         NaN
# 108       N         NaN
# 109       N         NaN
# 110       N         NaN
# 111       N         NaN
#
# [674 rows x 25 columns]

# %%
northeast_region.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 674 entries, 0 to 111
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Commodity Name   674 non-null    object
#  1   City Name        674 non-null    object
#  2   Type             0 non-null      float64
#  3   Package          674 non-null    object
#  4   Variety          672 non-null    object
#  5   Sub Variety      83 non-null     object
#  6   Grade            0 non-null      float64
#  7   Date             674 non-null    object
#  8   Low Price        674 non-null    int64
#  9   High Price       674 non-null    float64
#  10  Mostly Low       674 non-null    int64
#  11  Mostly High      674 non-null    float64
#  12  Origin           669 non-null    object
#  13  Origin District  81 non-null     object
#  14  Item Size        625 non-null    object
#  15  Color            356 non-null    object
#  16  Environment      0 non-null      float64
#  17  Unit of Sale     106 non-null    object
#  18  Quality          0 non-null      float64
#  19  Condition        0 non-null      float64
#  20  Appearance       0 non-null      float64
#  21  Storage          0 non-null      float64
#  22  Crop             0 non-null      float64
#  23  Repack           674 non-null    object
#  24  Trans Mode       0 non-null      float64
# dtypes: float64(11), int64(2), object(12)
# memory usage: 136.9+ KB

# %%
northeast_region.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 674 entries, 0 to 111
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Commodity Name   674 non-null    object
#  1   City Name        674 non-null    object
#  2   Type             0 non-null      float64
#  3   Package          674 non-null    object
#  4   Variety          672 non-null    object
#  5   Sub Variety      83 non-null     object
#  6   Grade            0 non-null      float64
#  7   Date             674 non-null    object
#  8   Low Price        674 non-null    int64
#  9   High Price       674 non-null    float64
#  10  Mostly Low       674 non-null    int64
#  11  Mostly High      674 non-null    float64
#  12  Origin           669 non-null    object
#  13  Origin District  81 non-null     object
#  14  Item Size        625 non-null    object
#  15  Color            356 non-null    object
#  16  Environment      0 non-null      float64
#  17  Unit of Sale     106 non-null    object
#  18  Quality          0 non-null      float64
#  19  Condition        0 non-null      float64
#  20  Appearance       0 non-null      float64
#  21  Storage          0 non-null      float64
#  22  Crop             0 non-null      float64
#  23  Repack           674 non-null    object
#  24  Trans Mode       0 non-null      float64
# dtypes: float64(11), int64(2), object(12)
# memory usage: 136.9+ KB

# %%
northeast_region["Type"].head(25)
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# Name: Type, dtype: float64

# %%
northeast_region["Appearance"].head(25)
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# Name: Appearance, dtype: float64

# %%
northeast_region.dropna(axis = 1, how = 'all')
# Out:
#     Commodity Name  City Name              Package      Variety Sub Variety  \
# 0         PUMPKINS  BALTIMORE         24 inch bins          NaN         NaN
# 1         PUMPKINS  BALTIMORE         24 inch bins          NaN         NaN
# 2         PUMPKINS  BALTIMORE         24 inch bins  HOWDEN TYPE         NaN
# 3         PUMPKINS  BALTIMORE         24 inch bins  HOWDEN TYPE         NaN
# 4         PUMPKINS  BALTIMORE         24 inch bins  HOWDEN TYPE         NaN
# ..             ...        ...                  ...          ...         ...
# 107       PUMPKINS   NEW YORK       bushel cartons    MINIATURE         NaN
# 108       PUMPKINS   NEW YORK  1 1/9 bushel crates    MINIATURE  ROUND TYPE
# 109       PUMPKINS   NEW YORK  1 1/9 bushel crates    MINIATURE  ROUND TYPE
# 110       PUMPKINS   NEW YORK  1 1/9 bushel crates    MINIATURE  ROUND TYPE
# 111       PUMPKINS   NEW YORK  1 1/9 bushel crates    MINIATURE  ROUND TYPE
#
#            Date  Low Price  High Price  Mostly Low  Mostly High    Origin  \
# 0    04/29/2017        270       280.0         270        280.0       NaN
# 1    05/06/2017        270       280.0         270        280.0       NaN
# 2    09/24/2016        160       160.0         160        160.0  DELAWARE
# 3    09/24/2016        160       160.0         160        160.0  VIRGINIA
# 4    11/05/2016         90       100.0          90        100.0  MARYLAND
# ..          ...        ...         ...         ...          ...       ...
# 107  09/09/2017         32        32.0          32         32.0      OHIO
# 108  10/08/2016         18        18.0          18         18.0  NEW YORK
# 109  10/08/2016         18        18.0          18         18.0  NEW YORK
# 110  10/15/2016         18        18.0          18         18.0  NEW YORK
# 111  10/15/2016         18        18.0          18         18.0  NEW YORK
#
#      Origin District Item Size Color Unit of Sale Repack
# 0                NaN       lge   NaN          NaN      E
# 1                NaN       lge   NaN          NaN      E
# 2                NaN       med   NaN          NaN      N
# 3                NaN       med   NaN          NaN      N
# 4                NaN       lge   NaN          NaN      N
# ..               ...       ...   ...          ...    ...
# 107              NaN       sml   NaN          NaN      N
# 108  WESTERN SECTION       med   NaN          NaN      N
# 109  WESTERN SECTION       sml   NaN          NaN      N
# 110  WESTERN SECTION       med   NaN          NaN      N
# 111  WESTERN SECTION       sml   NaN          NaN      N
#
# [674 rows x 16 columns]

# %% [raw]
# northeast = northeast_region.dropna(axis = 1, how = 'all')

# %% [raw]
# northeast_region.info()

# %% [markdown]
# ## Combine Your Data
#
# Now that you have four clean sets of data, combine all four into one dataframe that represents the entire Northeast region.

# %%
# Combine the four dataframes into one!
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\DMORRI~1\AppData\Local\Temp/ipykernel_29708/3883523107.py in <module>
#       1 # Combine the four dataframes into one!
# ----> 2 northeast_region=pd.concat([baltimore_df, boston_df, philly_df, ny_df])
#       3 northeast_region.info()
#
# NameError: name 'baltimore_df' is not defined

# %% [markdown]
# ## Answer Some Questions
#
# Use `groupby()` and `agg()` to answer the following two questions:
#
# 1. What is the mean low and high prices for each type of unit of sale in the Northeast region? In the last lesson, we learned that a unit of sale could be something like a bin or individually.
# 2. What is the average number of pumpkins for each variety that came into terminal markets for the year by region? Pumpkin varieties include Howden and Fairytale pumpkins.

# %%
# Put your code here to find the mean low and high prices in the Northeast region for each type of unit of sale.
northeast['Unit of sale'].dropna().value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\DMORRI~1\AppData\Local\Temp/ipykernel_29708/1516997959.py in <module>
#       1 # Put your code here to find the mean low and high prices in the Northeast region for each type of unit of sale.
# ----> 2 northeast['Unit of sale'].dropna().value_counts()
#
# NameError: name 'northeast' is not defined

# %%
northeast[(northeast['Unit of Sale']=='PER BIN')].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\DMORRI~1\AppData\Local\Temp/ipykernel_29708/1976562209.py in <module>
# ----> 1 northeast[(northeast['Unit of Sale']=='PER BIN')]
#
# NameError: name 'northeast' is not defined

# %%
# Put your code here to find the average number of pumpkins coming into terminal markets of each variety.
northeast[(northeast['Unit of Sale']=='EACH')].describe()

# %%
northeast[(northeast['Unit of Sale']=='SHELLACKED')].describe()

# %%
northeast.groupby(['Unit of Sale'])

# %%
northeast
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\DMORRI~1\AppData\Local\Temp/ipykernel_29708/1164757662.py in <module>
# ----> 1 northeast
#
# NameError: name 'northeast' is not defined

# %% [raw]
# northeast.groupby(['Unit of Sale']).mean()

# %%
northeast_df.groupby('Unit of Sale').agg({'Low Price':'mean'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\DMORRI~1\AppData\Local\Temp/ipykernel_29708/1150682857.py in <module>
# ----> 1 northeast_df.groupby('Unit of Sale').agg({'Low Price':'mean'})
#
# NameError: name 'northeast_df' is not defined

# %% [markdown]
# ## Bonus Mission
#
# Try answering the same questions for the Midwest (Chicago, Detroit, and St. Louis) or the Southeast (Atlanta, Columbia, and Miami) regions.

# %%
# Try the bonus mission if you have time!
